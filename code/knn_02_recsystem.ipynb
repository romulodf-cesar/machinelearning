# %% [markdown]
# # RecSystem Movies

# %% [markdown]
# ## DataSet

# %%
! pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ------------------- -------------------- 4.7/9.7 MB 29.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 29.4 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
# ...

# %%
import pandas as pd

# %%
df_movies = pd.read_csv('datasets/movies.csv')

# %%
df_movies.columns = ['id_filme', 'titulo', 'genero']

# %%
df_movies = df_movies.set_index('id_filme')

# %%
df_movies.head()
# Out:
#    id_filme                              titulo  \
# 0         1                    Toy Story (1995)
# 1         2                      Jumanji (1995)
# 2         3             Grumpier Old Men (1995)
# 3         4            Waiting to Exhale (1995)
# 4         5  Father of the Bride Part II (1995)
#
#                                         genero
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %% [markdown]
# # Carregar o dataframe de notas

# %%
df_ratings = pd.read_csv('datasets/ratings.csv')
df_ratings.columns = ['id_usuario', 'id_filme', 'nota', 'momento']
df_ratings.head()
# Out:
#    id_usuario  id_filme  nota    momento
# 0           1         1   4.0  964982703
# 1           1         3   4.0  964981247
# 2           1         6   4.0  964982224
# 3           1        47   5.0  964983815
# 4           1        50   5.0  964982931

# %%
df_ratings.describe()
# Out:
#           id_usuario       id_filme           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df_ratings.nota.min()
# Out:
# np.float64(0.5)

# %%
df_ratings.nota.max()
# Out:
# np.float64(5.0)

# %% [markdown]
# # Primeira Recomendação

# %%
df_ratings['id_filme'].value_counts().head(3)
# Out:
# id_filme
# 356    329
# 318    317
# 296    307
# Name: count, dtype: int64

# %%
df_movies.loc[356]
# Out:
# titulo         Forrest Gump (1994)
# genero    Comedy|Drama|Romance|War
# Name: 356, dtype: str

# %%
# total de votos
total_votos = df_ratings['id_filme'].value_counts()
total_votos.head()
# Out:
# id_filme
# 356     329
# 318     317
# 296     307
# 593     279
# 2571    278
# Name: count, dtype: int64

# %%
total_votos.shape
# Out:
# (9724,)

# %%
print(type(total_votos))
# Out:
# <class 'pandas.Series'>

# %%
df_movies.head()
# Out:
#                                       titulo  \
# id_filme
# 1                           Toy Story (1995)
# 2                             Jumanji (1995)
# 3                    Grumpier Old Men (1995)
# 4                   Waiting to Exhale (1995)
# 5         Father of the Bride Part II (1995)
#
#                                                genero
# id_filme
# 1         Adventure|Animation|Children|Comedy|Fantasy
# 2                          Adventure|Children|Fantasy
# 3                                      Comedy|Romance
# 4                                Comedy|Drama|Romance
# 5                                              Comedy

# %%
df_movies['total_votos'] = total_votos

# %%
df_movies.head()
# Out:
#                                       titulo  \
# id_filme
# 1                           Toy Story (1995)
# 2                             Jumanji (1995)
# 3                    Grumpier Old Men (1995)
# 4                   Waiting to Exhale (1995)
# 5         Father of the Bride Part II (1995)
#
#                                                genero  total_votos
# id_filme
# 1         Adventure|Animation|Children|Comedy|Fantasy        215.0
# 2                          Adventure|Children|Fantasy        110.0
# 3                                      Comedy|Romance         52.0
# 4                                Comedy|Drama|Romance          7.0
# 5                                              Comedy         49.0

# %%
df_ratings.head(3)
# Out:
#    id_usuario  id_filme  nota    momento
# 0           1         1   4.0  964982703
# 1           1         3   4.0  964981247
# 2           1         6   4.0  964982224

# %%
# ordenar crescente
df_movies.sort_values('total_votos', ascending=False).head(10)
# Out:
#                                              titulo  \
# id_filme
# 356                             Forrest Gump (1994)
# 318                Shawshank Redemption, The (1994)
# 296                             Pulp Fiction (1994)
# 593                Silence of the Lambs, The (1991)
# 2571                             Matrix, The (1999)
# 260       Star Wars: Episode IV - A New Hope (1977)
# 480                            Jurassic Park (1993)
# 110                               Braveheart (1995)
# 589               Terminator 2: Judgment Day (1991)
# 527                         Schindler's List (1993)
#
#                                     genero  total_votos
# id_filme
# 356               Comedy|Drama|Romance|War        329.0
# 318                            Crime|Drama        317.0
# 296            Comedy|Crime|Drama|Thriller        307.0
# 593                  Crime|Horror|Thriller        279.0
# 2571                Action|Sci-Fi|Thriller        278.0
# ...

# %%
os_tres_indicados = df_movies.sort_values('total_votos', ascending=False).head(3)
os_tres_indicados
# Out:
#                                     titulo                       genero  \
# id_filme
# 356                    Forrest Gump (1994)     Comedy|Drama|Romance|War
# 318       Shawshank Redemption, The (1994)                  Crime|Drama
# 296                    Pulp Fiction (1994)  Comedy|Crime|Drama|Thriller
#
#           total_votos
# id_filme
# 356             329.0
# 318             317.0
# 296             307.0

# %% [markdown]
# # BOM FILME!

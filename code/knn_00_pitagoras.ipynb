# %% [markdown]
# # ferramentas

# %% [markdown]
# * Visual Studio Code
# * Jupyter Notebook
# * Anaconda (ecossistema de ferramentas)

# %% [markdown]
# # Conceitos de IA

# %% [markdown]
# * 1950: IA Classica (inverno da IA)
# * Warren McCulloch (Neurocientista) e Walter Pitts (TI (eletrônica)) em 1943
# * Machine Learning para Negócios (funções/estatística)
# * Machine Learning é uma IA
# * Redes Neurais (Big Data) - DataBricks
# * Redes Neurais Convolucionais
# * Machine Learning é indicado para Negócios (Ache Fácil)
# * Prever o valor de vendas : Machine Learning Supervisonado -Regressão
# * Prever se o cliente vai comprar (sim) ou (não) determinado produto
# * Disruptiva
# * www.psul.com.br  (paixão)
# * Ache Fácil (Box1   ------ Pessoa1)
# * Sistema de Recomendação - target (valor) = nota

# %% [markdown]
# # Machine Learning Supervisionado por Regressão (sistema de recomendação)

# %% [markdown]
# ## A base para aprender o algoritmo KNN

# %% [markdown]
# ### Teorema de Pitagoras

# %% [markdown]
# - Samos
# - o quadrado da hipotenusa é igual à soma dos quadrados dos catetos.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Considerando o valor de a = 5 e b = 10 qual o valor de c (teorema de pitágoras)
import math

a = 5
b = 10
c = math.sqrt(a**2 + b**2)
print(f"O valor de c é: {c}")
# Out:
# O valor de c é: 11.180339887498949

# %% [markdown]
# ### Distância Euclidiana

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### ScikitLearn

# %% [markdown]
# ### KNN

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class DistanciaEuclidiana:
    pass
